# %% [markdown]
# ## * LETICIA POMAA ODOOM
# ## * 11013476
# ## * BIOMEDICAL ENGINEERING

# %%
# QUESTION 1

# %%
# REQUIRED LIBRARIES 


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
#sns.set(color_codes = True)
import warnings
warnings.filterwarnings('ignore')

# %%
# QUESTION 3

# %%
dataset = pd.read_csv('red_wine (3).csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# QUESTION 4

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# QUESTION 5

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
# QUESTION 6

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
# QUESTION 7

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
# QUESTION 8

# %%
# Plotting the histogram using mean, std, min, and max values provided for fixed acidity
plt.figure(figsize=(8, 6))
plt.hist([8.318335, 4.6, 15.9, 1.740863], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Fixed Acidity')
plt.ylabel('Frequency')
plt.title('Distribution of Fixed Acidity')
plt.grid(True)
plt.show()

# %% [markdown]
# # Correlation Matrix Heatmap
# ## Tthe correlation heatmap reveals the relationships between all the differnt variables in the dataset.
# *
#
# Alcohole and Quality show a very positve correlation.

# %%
# A Distribution of Alcohol
plt.figure(figsize=(10, 6))
plt.hist(dataset['alcohol'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Alcohol')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Distribution of Alcohol Content
# ###
# The histogram below illustrates the distribution of alcohol content in the dataset. Most wines have an alcohol content between 9.4% and 9.8%..

# %%
# A boxplot for Boxplot of Quality by Alcohol
plt.figure(figsize=(12, 8))
dataset.boxplot(column='quality', by='alcohol', grid=False,color='skyblue')
plt.title('Boxplot of Quality by Alcohol')
plt.suptitle('')
plt.show()

# %% [markdown]
# # Boxplot of Quality vs. Alcohol Content
# ###
# The boxplot visually depicts the relationship between wine quality and alcohol content.It suggests that wines with higher quality tend to have slightly higher alchole content

# %% [markdown]
# # Histogram of pH
# ###
# The histogram displays the distribution of pH values in the darkest. Most wines have a pH around 3.3

# %%
# Bar chart of Quality using Matplotlib
plt.figure(figsize=(8, 5))
quality_counts = dataset['quality'].value_counts().sort_index()
plt.bar(quality_counts.index, quality_counts, color='green',edgecolor='black')
plt.title('Bar Chart of Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Bar Chart of Wine Quality
# ###
# The bar chart provides a count of wines for each quality rating. Most wines in the dataset have a quality rating of 5.#
#
# Bar chart of Quality using Matplotlview

# %% [markdown]
# # Dataset Overview
# Fixed Acidit,y
# Volatility Acidi,ty
# Citric A,cid
# Residual S,ugar
# Chlo,rides
# Free Sulfur D,ioxide
# Total Sulfur ,Dioxide
# ,
# De,nsity
# pH
# ,
# Sulphat,es
# Alcohol
# Quality

# %%
# heatmap of the correlations between variables
plt.figure(figsize=(10, 10))
sns.heatmap(dataset.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.title('Correlation Matrix')
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Fixed Acidity')
plt.title('Scatter Plot: Fixed Acidity vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([0.527747, 0.12, 1.58, 0.179092], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Volatile Acidity')
plt.ylabel('Frequency')
plt.title('Distribution of Volatile Acidity')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([0.270976, 0, 1, 0.194801], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Citric Acid')
plt.ylabel('Frequency')
plt.title('Distribution of Citric Acid')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Citric Acid')
plt.title('Scatter Plot: Citric Acid vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([2.538806, 0.9, 15.5, 1.409928], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Residual Sugar')
plt.ylabel('Frequency')
plt.title('Distribution of Residual Sugar')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Residual Sugar')
plt.title('Scatter Plot: Residual Sugar vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([0.087476, 0.012, 0.611, 0.047117], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Chlorides')
plt.ylabel('Frequency')
plt.title('Distribution of Chlorides')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Chlorides')
plt.title('Scatter Plot: Chlorides vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([15.867334, 1, 72, 10.459029], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Free Sulfur Dioxide')
plt.ylabel('Frequency')
plt.title('Distribution of Free Sulfur Dioxide')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Free Sulfur Dioxide')
plt.title('Scatter Plot: Free Sulfur Dioxide vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([46.467792, 6, 289, 32.895324], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Total Sulfur Dioxide')
plt.ylabel('Frequency')
plt.title('Distribution of Total Sulfur Dioxide')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Total Sulfur Dioxide')
plt.title('Scatter Plot: Total Sulfur Dioxide vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([0.996746, 0.99007, 1.00369, 0.001887], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Density')
plt.ylabel('Frequency')
plt.title('Distribution of Density')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('pH')
plt.title('Scatter Plot: pH vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([0.658149, 0.33, 2, 0.169507], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Sulphates')
plt.ylabel('Frequency')
plt.title('Distribution of Sulphates')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Sulphates')
plt.title('Scatter Plot: Sulphates vs. Quality')
plt.grid(True)
plt.show()

# %%
# Plotting the histogram using mean, std, min, and max values provided
plt.figure(figsize=(8, 6))
plt.hist([10.422983, 8.4, 14.9, 1.065668], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')
plt.title('Distribution of Alcohol')
plt.grid(True)
plt.show()

# %%
# Plotting a scatter plot using mean, min, max values provided against quality levels
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.title('Scatter Plot: Alcohol vs. Quality')
plt.grid(True)
plt.show()

# %%
dataset = pd.DataFrame({
    'Fixed Acidity': [8.318335],
    'Volatile Acidity': [0.527747],
    'Citric Acid': [0.270976],
    'Residual Sugar': [2.538806],
    'Chlorides': [0.087476],
    'Free Sulfur Dioxide': [15.867334],
    'Total Sulfur Dioxide': [46.467792],
    'Density': [0.996746],
    'pH': [3.311113],
    'Sulphates': [0.658149],
    'Alcohol': [10.422983],
    'Quality': [5.635795]
})

plt.figure(figsize=(12, 8))
for column in dataset.columns:
    plt.hist(dataset[column], bins=10, alpha=0.5, label=column)

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Combined Histogram of Variables')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dataset['Alcohol'], dataset['Quality'], alpha=0.8, color='green')
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('Scatter Plot: Quality vs. Alcohol')
plt.grid(True)
plt.show()

# %%
# QUESTION 9

# %% [markdown]
# #### VOLATILE ACIDITY: The distribution of volatile acidity is represented by a histogram that shows a range of about 0.12 to 1.58. The skewness of the distribution suggests that most samples often fall into a moderate range of volatile acidity values. The peak at approximately 0.53, the mean value, indicates that volatile acidity is frequently observed in this range. This distribution suggests that the volatile acidity of the dataset has a variable composition, with a skew towards lower to moderate levels. There appears to be a patchy association between volatile acidity and wine quality, as seen in the scatter plot that compares volatile acidity against quality levels. Higher grade wines (identified by higher quality levels) are generally observed to have slightly lower volatile acidity on average, however this relationship is not clearly linear. Still,
#
# #### CITRIC ACID: The distribution of citric acid is represented by a histogram with values roughly ranging from 0 to 1. The distribution seems to be slightly skewed, suggesting that most samples typically have values of citric acid in the moderate range. The peak at about 0.27, the mean value, indicates that citric acid is frequently found in this range. This skewed distribution suggests that the content of citric acid ranges from lower to moderate values throughout the dataset. Nothing immediately stands out as a trend in the scatter plot that shows citric acid vs quality levels. On the other hand, the correlation between citric acid and wine quality appears to be erratic. There is a propensity for variable citric acid in higher-quality wines, as indicated by higher quality levels.
#
# #### RESIDUAL SUGAR: The histogram representing the distribution of residual sugar spans values from approximately 0.9 to 15.5. This distribution appears slightly skewed, indicating that most samples tend to have residual sugar values within a moderate range. The peak around the mean value of roughly 2.54 suggests a prevalent occurrence of residual sugar within this range. This skewed distribution implies a varied composition of residual sugar across the dataset, with a concentration towards lower to moderate values. Regarding the scatter plot illustrating residual sugar against quality levels, a discernible trend isn't immediately apparent. However, there seems to be a scattered relationship between residual sugar and wine quality. Higher-quality wines, represented by higher quality levels, exhibit a varied range of residual sugar levels. However, the correlation between residual sugar and wine quality appears to be subtle and not distinctly defined.
#
# #### CHLORIDES: The distribution of chlorides is represented by a histogram with values ranging roughly from 0.012 to 0.611. It can be observed from the distribution's mild skewness that most samples have chloride concentrations in the moderate range. The bump near the mean value of about 0.087 indicates that chlorides are frequently found in this area. This skewed distribution suggests that the dataset's chloride composition varies, with concentrations leaning towards lower to moderate values. In the scatter plot that shows chlorides vs quality levels, no obvious linear trend is seen. On the other hand, the correlation between chlorides and wine quality appears to be erratic. Higher grade wines have a wider range of chloride levels, as shown by higher quality levels. There seems to be a relationship between wine quality and chlorides.
#
# #### FREE SULPHUR DIOXIDE: The distribution of free sulphur dioxide is represented by a histogram with values ranging roughly from 1 to 72. The distribution seems to be skewed, suggesting that most samples typically contain free sulphur dioxide readings around the middle of the range. The peak at approximately 15.87, the mean value, indicates that free sulphur dioxide is present in this range on a regular basis. With a concentration leaning towards lower to moderate values, this skewed distribution suggests that the free sulphur dioxide composition varies over the sample. There isn't a clear linear trend apparent in the scatter plot that shows free sulphur dioxide against quality levels. The link between free sulphur dioxide and wine quality, however, appears to be erratic. Higher grade levels, which correspond to higher quality wines, show
#
# #### TOTAL SULPHUR DIOXIDE: The distribution of total sulphur dioxide is represented by a histogram that ranges in values from roughly 6 to 289. The distribution looks to be highly skewed, suggesting that most samples typically have concentrations towards lower values and total sulphur dioxide values within a modest range. The peak at the mean value of 46.47 indicates that total sulphur dioxide is frequently found in this area. This skewed distribution suggests that the overall sulphur dioxide content of the dataset varies, with a significant concentration towards lower values. There isn't a discernible linear trend in the scatter plot that shows total sulphur dioxide versus quality levels. On the other hand, the correlation between total sulphur dioxide and wine quality appears to be erratic. superior wines, as demonstrated by higher quality levels, exhibit a varied range of total sulfur dioxide levels. The correlation between total sulfur dioxide and wine quality appears to be subtle and not distinctly defined.
#
# #### DENSITY: The density distribution is represented by a histogram that ranges in values from roughly 0.990 to 1.004. The distribution appears to be centred around the mean value, which is approximately 0.997, and rather symmetrical. This implies that density values are typically distributed around this mean in the majority of samples. The majority of the values in the histogram are centred around the mean, indicating a very regular distribution of density throughout the dataset. There isn't a clear linear trend shown in the scatter plot that shows density against quality levels. Nonetheless, the correlation between density and wine quality seems to be erratic. Higher quality wines exhibit a range of densities, as indicated by their quality ratings. However, it appears that there is a weak and hazy relationship between density and wine quality.Higher-quality wines, indicated by higher quality levels, showcase varied density levels. Nevertheless, the correlation between density and wine quality seems to be subtle and not sharply defined.
#
# #### pH: The distribution of pH is represented by a histogram that ranges from roughly 2.74 to 4.01. The distribution seems to be centred around the mean value, which is approximately 3.31, and rather symmetrical. This suggests that pH readings tend to be grouped around this mean in the majority of samples. With the majority of values clustered around the mean, the histogram indicates that the pH values in the dataset have a rather normal distribution. There isn't a clear linear trend showing in the scatter plot that compares pH to quality levels. Nonetheless, there appears to be a sporadic correlation between wine quality and pH. Higher quality wines have different pH values, which are represented by higher quality levels. However, it seems that there is a weak and ambiguous relationship between pH and wine quality.Higher-quality wines, indicated by higher quality levels, exhibit varied pH levels. Nevertheless, the correlation between pH and wine quality appears to be subtle and not strongly defined.
#
# #### SULPHATES: The distribution of sulphates is shown by a histogram with values ranging from roughly 0.33 to 2. The distribution seems to be slightly skewed, suggesting that most samples typically contain sulphate levels in the moderate range. The peak at approximately 0.66, the mean value, indicates that sulphates are frequently found in this range. This skewed distribution suggests that the dataset's sulphate composition varies, with concentrations leaning towards lower to intermediate values. There is no discernible linear trend in the scatter plot that shows sulphates against grade levels. Still, there appears to be conflicting evidence linking sulphates to wine quality. Sulphur content varies amongst higher-quality wines, as denoted by higher grade levels. However, it seems that there is only a slight relationship between sulphates and wine quality.
#
# #### ALCOHOL: The alcohol histogram displays a distribution that falls between around 8.4 and 14.9. The distribution appears to be rather skewed, indicating that most samples typically have alcohol contents that fall into a particular moderate range. The alcohol percentage within this range is commonly seen, as indicated by the peak around the mean value of about 10.42. This skewed distribution suggests that the alcohol content in the dataset is composed differently, with a concentration leaning towards moderate levels. There appears to be a slight trend in the scatter plot that compares alcohol content to quality levels. The correlation between wine quality and alcohol concentration seems to be erratic. Higher quality levels are indicative of higher-quality wines, which typically have a marginally higher average alcohol content. Still, even though a  trend is noticeable, the correlation between alcohol content and wine quality might not be extremely strong or linear.
#
# ## SUMMARY: Because distinct variables have varied sizes and ranges of features, combining many variables into a single histogram may not give a comprehensive overview. It can, however, provide an overview of their distributions in a single visualisation. The distributions of different wine characteristics, such as fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, total sulphur dioxide, free sulphur dioxide, density, pH, sulphates, alcohol, and quality, are shown in the combined histogram. The histogram displays the distribution of each attribute in a variety of colours. The scatter plot that compares the variables "quality" and "alcohol" illustrates the link between these two variables. There appears to be a modest tendency suggesting that wines of higher grade may have an average alcohol concentration that is slightly higher. But this association isn't clear-cut, so more research may be necessary.

# %%
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
